# %% [markdown]
# # Multi-ETF Municipal Bond Screener
#
# This notebook uses the same reusable data engine as the Streamlit app: `src/muni_data.py`.

# %%
# %pip install -q -r ../requirements.txt

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.muni_data import load_all_ishares_munis, screen_munis

# %%
df, source_rows, etf_status, as_of = load_all_ishares_munis()
print(f'Unique CUSIPs: {len(df):,}')
print(f'Raw ETF rows: {len(source_rows):,}')
print(f'Latest source date: {as_of}')
display(etf_status.sort_values(['Status', 'Ticker']).reset_index(drop=True))

# %%
results = screen_munis(
    df,
    purchase_face=5000,
    sort_by='YTW: High → Low',
)
display(results.head(100))

# %% [markdown]
# ## Example filters

# %%
filtered = screen_munis(
    df,
    states=['Indiana'],
    purchase_face=5000,
    price_min=95,
    price_max=105,
    coupon_min=4.0,
    investment_grade_only=True,
    sort_by='YTW: High → Low',
)
display(filtered.head(100))
